# %%
""" key = "// Import the functions you need from the SDKs you need
import { initializeApp } from "firebase/app";
import { getAnalytics } from "firebase/analytics";
// TODO: Add SDKs for Firebase products that you want to use
// https://firebase.google.com/docs/web/setup#available-libraries

// Your web app's Firebase configuration
// For Firebase JS SDK v7.20.0 and later, measurementId is optional
const firebaseConfig = {
  apiKey: "AIzaSyA_OHj-rYlli9F_iKUIIQc8sotBhDrM--4",
  authDomain: "pochacco-todolist.firebaseapp.com",
  projectId: "pochacco-todolist",
  storageBucket: "pochacco-todolist.firebasestorage.app",
  messagingSenderId: "724748524737",
  appId: "1:724748524737:web:d66871f7270a6648388840",
  measurementId: "G-3KGD959HCV"
};

// Initialize Firebase
const app = initializeApp(firebaseConfig);
const analytics = getAnalytics(app);"" """

# %%
flowchart TD
    Root[index.html Root] --> Body[body 배경 그라데이션]
    Body --> Canvas[canvas id='confetti-canvas' 폭죽 독립 레이어]
    Body --> Main[main 포차코 화이트-크림 카드 카드]
    
    Main --> Loading[div id='loading-overlay' 접속 대기 화면]
    Main --> Mascot[포차코 마스코트 영역]
    Mascot --> SVG[svg id='pochacco-svg' 캐릭터 모델]
    Mascot --> Speech[div id='speech-bubble' 대화 말풍선]
    
    Main --> Toggle[button 달력 접기/열기 아코디언 토글]
    Main --> CalContainer[div id='calendar-container' 달력 격자무대]
    CalContainer --> CalHeader[달력 연도/월 전환 헤더 및 제어 단추]
    CalContainer --> Weekdays[요일 텍스트 바 일~토]
    CalContainer --> CalDays[div id='calendar-days' 날짜 선택 셀]
    
    Main --> DateBar[선택 날짜 & 남은 할 일 칩 바]
    Main --> Form[form id='todo-form' 할 일 텍스트 입력 양식]
    Main --> TodoList[div id='todo-list' 실시간 정렬 할 일 목록]
    TodoList --> TodoItem[Todo Item 개별 행 카드]
    TodoItem --> Checkbox[완료 체크 박스 및 서클]
    TodoItem --> DeleteBtn[삭제 휴지통 버튼]
    
    Main --> EmptyState[div id='empty-state' 계획 부재 시 팁 영역]
    
    Body --> RulesModal[div id='rules-modal' 권한 가이드 모달]
    Body --> Toast[div id='toast' 경고 팝업 가이드]
    Body --> Footer[footer 저작권 및 꼬리말]

    %% Style 정의 %%
    style Root fill:#F5F5F5,stroke:#333,stroke-width:2px
    style Main fill:#FFFEEF,stroke:#333,stroke-width:2px
    style SVG fill:#FFFFFF,stroke:#333,stroke-width:2px
# Out:
#   Cell In[1], line 1
#     flowchart TD
#               ^
# SyntaxError: invalid syntax
